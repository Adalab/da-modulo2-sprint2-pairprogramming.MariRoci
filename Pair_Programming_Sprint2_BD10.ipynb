# %% [markdown]
# # Pair programming Gestión de Ficheros

# %% [markdown]
# En este pair vamos a trabajar la apertura y exploración de archivos. Para finalmente guardar el archivo con un formato diferente.
#
# vamos a utilizar el fichero videogames.csv

# %%
import xml.etree.ElementTree as ET
import json
import pandas as pd

# %% [markdown]
# 1. Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pandas.

# %%
df_videogames = pd.read_csv("videogames.csv")

# %% [markdown]
# 2. Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
df_videogames = pd.read_csv("videogames.csv", index_col=0)

# %%
df_videogames.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %% [markdown]
# 3. Una vez creado el Dataframe, muestra las 10 primeras filas.

# %%
df_videogames.head(10)
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
# 5     The Last of Us: Part II
# 6      Horizon Forbidden West
# 7              The Last of Us
# 8       Detroit: Become Human
# 9             Death Stranding
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# 5  https://www.imdb.com/title/tt6298000/?ref_=adv...  2020.0           M
# 6  https://www.imdb.com/title/tt12496904/?ref_=ad...  2022.0           T
# ...

# %% [markdown]
# 4. ¿Cúal es el último índice que tenemos en el Dataframe?

# %%
df_videogames.tail(1)
# Out:
#           name                                                url    year  \
# 20802  Cryptic  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0
#
#       certificate  rating votes  \
# 20802         NaN     NaN   NaN
#
#                                                     plot  Action  Adventure  \
# 20802  Kidnapped by an insane man and dragged into a ...   False      False
#
#        Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 20802   False  False   False    False    False   False      True

# %%
print ('El último índice de nuesto data frame es el 20802 (tenemos 20803 filas)')
# Out:
# El último índice de nuesto data frame es el 20802 (tenemos 20803 filas)

# %% [markdown]
# 5. Mostrar 15 filas aleatorias.

# %%
df_videogames.sample(n=15)
# Out:
#                                        name  \
# 17882         The Binding of Isaac: Rebirth
# 12760  Angelo & Deemon: One Hell of a Quest
# 19794                            Consortium
# 16546                             Make Trax
# 15128                              Ara Fell
# 456                   ARK: Genesis - Part 2
# 7934                         Karate Blazers
# 8316              Tokumei Sentai Go-Busters
# 8674                        Jazz Jackrabbit
# 8240                         Ecks vs. Sever
# 14438                       King of Thieves
# 11720                       Angels of Death
# 6877                       Space Encounters
# 3404                  Destiny: Rise of Iron
# 14828          Driftland: The Magic Revival
#
#                                                      url    year certificate  \
# 17882  https://www.imdb.com/title/tt4276210/?ref_=adv...  2014.0           M
# 12760  https://www.imdb.com/title/tt10487280/?ref_=ad...  2019.0         NaN
# ...

# %% [markdown]
# 6. Crea una lista con el nombre de las columnas.

# %%
df_videogames.columns.tolist()
# Out:
# ['name',
#  'url',
#  'year',
#  'certificate',
#  'rating',
#  'votes',
#  'plot',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Family',
#  'Fantasy',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller']

# %% [markdown]
# 7. Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?

# %%
df_videogames.to_excel("videogames.xlsx")

# %%
df_videogames_excel = pd.read_excel("videogames.xlsx",index_col=0)

# %%
df_videogames.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %%
print ('Sí: ambos dataframe son iguales')

# %% [markdown]
# 8. Muestra la "info" del Dataframe.

# %%
df_videogames_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20803 entries, 0 to 20802
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         20803 non-null  object
#  1   url          20803 non-null  object
#  2   year         20536 non-null  float64
#  3   certificate  7903 non-null   object
#  4   rating       11600 non-null  float64
#  5   votes        11600 non-null  object
#  6   plot         20803 non-null  object
#  7   Action       20803 non-null  bool
#  8   Adventure    20803 non-null  bool
#  9   Comedy       20803 non-null  bool
#  10  Crime        20803 non-null  bool
#  11  Family       20803 non-null  bool
#  12  Fantasy      20803 non-null  bool
#  13  Mystery      20803 non-null  bool
#  14  Sci-Fi       20803 non-null  bool
#  15  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# 9. ¿Tiene nulos o duplicados?

# %%
valores_nulos_por_columna = df_videogames_excel.isnull().sum()
print("Valores nulos por columna:")
print(valores_nulos_por_columna)
# Out:
# Valores nulos por columna:
# name               0
# url                0
# year             267
# certificate    12900
# rating          9203
# votes           9203
# plot               0
# Action             0
# Adventure          0
# Comedy             0
# Crime              0
# Family             0
# Fantasy            0
# Mystery            0
# Sci-Fi             0
# Thriller           0
# dtype: int64

# %%
duplicados = df_videogames_excel.duplicated().sum()
print("\nCantidad de filas duplicadas:", duplicados)
# Out:
# Cantidad de filas duplicadas: 1

# %% [markdown]
# 10. Obtener la descripción del Dataframe, tanto de las columnas numéricas cómo de las de tipo "object". Explorar el resultado y sacar unas mínimas conclusiones sobre los datos que habéis obtenido.

# %%
# Obtener estadísticas descriptivas para columnas numéricas
descripcion_numericas = df_videogames.describe()
print("Estadísticas descriptivas para columnas numéricas:")
print(descripcion_numericas)
# Out:
# Estadísticas descriptivas para columnas numéricas:
#                year        rating
# count  20536.000000  11600.000000
# mean    2005.568611      7.047526
# std       11.846028      1.235204
# min     1952.000000      1.000000
# 25%     1997.000000      6.400000
# 50%     2008.000000      7.200000
# 75%     2016.000000      7.900000
# max     2027.000000      9.700000

# %% [markdown]
# # conclusiones sobre los años de los videojuegos:
#  - la media de año de los videojuegos es el año 2005
#  - el primer año con datos es 1952 y el último año con datos es 2027 (entendemos que se refieren a año de lanzamiento del videojuego)
#  - el 25% de los datos son de años entre 1952 y 1997
#  - el 50% de los datos son de años entre 1952 y 2008
#  - el 75% de los datos son de años entre 1952 y 2016
#  - deducimos que el 25% de los datos restantes se componen en fecha de lanzamiento entre 2017 y 2027

# %%
# Obtener información de las columnas de tipo "object"
columnas_object = df_videogames.select_dtypes(include='object').columns.tolist()

for columna in columnas_object:
    print(f"\nInformación para la columna '{columna}':")
    print(f"Número de valores únicos: {df_videogames[columna].nunique()}")
    print("Valores únicos:")
    print(df_videogames[columna].unique())
    print("\nConteo de valores:")
    print(df_videogames[columna].value_counts())
# Out:
# Información para la columna 'name':
# Número de valores únicos: 19714
# Valores únicos:
# ['Spider-Man' 'Red Dead Redemption II' 'Grand Theft Auto V' ... 'Shutter'
#  'The Music Machine' 'Cryptic']
#
# Conteo de valores:
# Spider-Man                        9
# God of War                        6
# Sonic the Hedgehog                6
# Star Trek                         6
# Resident Evil 2                   5
#                                  ..
# Elevator Action                   1
# Nobuyuki Forces 4                 1
# Cross Fire: king of gun battle    1
# Duke: Nuclear Winter              1
# Cryptic                           1
# Name: name, Length: 19714, dtype: int64
#
# Información para la columna 'url':
# Número de valores únicos: 20157
# Valores únicos:
# ['https://www.imdb.com/title/tt5807780/?ref_=adv_li_tt'
#  'https://www.imdb.com/title/tt6161168/?ref_=adv_li_tt'
#  'https://www.imdb.com/title/tt2103188/?ref_=adv_li_tt' ...
# ...

# %% [markdown]
# 11. Finalmente, guarda el Dataframe en formato "csv" con un nombre diferente del original.

# %%
df_videogames.to_csv("videojuegos.csv")
